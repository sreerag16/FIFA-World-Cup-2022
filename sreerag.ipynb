# %% [markdown]
# ## Importing required libraries.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Importing Dataset using pandas

# %%
df = pd.read_csv('international_matches.csv')

# %%
df.shape
# Out:
# (23921, 25)

# %%
df.head()
# Out:
#          date home_team     away_team home_team_continent away_team_continent  \
# 0  1993-08-08   Bolivia       Uruguay       South America       South America
# 1  1993-08-08    Brazil        Mexico       South America       North America
# 2  1993-08-08   Ecuador     Venezuela       South America       South America
# 3  1993-08-08    Guinea  Sierra Leone              Africa              Africa
# 4  1993-08-08  Paraguay     Argentina       South America       South America
#
#    home_team_fifa_rank  away_team_fifa_rank  home_team_total_fifa_points  \
# 0                   59                   22                            0
# 1                    8                   14                            0
# 2                   35                   94                            0
# 3                   65                   86                            0
# 4                   67                    5                            0
#
# ...

# %%
df.tail()
# Out:
#              date       home_team away_team home_team_continent  \
# 23916  2022-06-14         Moldova   Andorra              Europe
# 23917  2022-06-14   Liechtenstein    Latvia              Europe
# 23918  2022-06-14           Chile     Ghana       South America
# 23919  2022-06-14           Japan   Tunisia                Asia
# 23920  2022-06-14  Korea Republic     Egypt                Asia
#
#       away_team_continent  home_team_fifa_rank  away_team_fifa_rank  \
# 23916              Europe                  180                  153
# 23917              Europe                  192                  135
# 23918              Africa                   28                   60
# 23919              Africa                   23                   35
# 23920              Africa                   29                   32
#
#        home_team_total_fifa_points  away_team_total_fifa_points  \
# 23916                          932                         1040
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23921 entries, 0 to 23920
# Data columns (total 25 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   date                           23921 non-null  object
#  1   home_team                      23921 non-null  object
#  2   away_team                      23921 non-null  object
#  3   home_team_continent            23921 non-null  object
#  4   away_team_continent            23921 non-null  object
#  5   home_team_fifa_rank            23921 non-null  int64
#  6   away_team_fifa_rank            23921 non-null  int64
#  7   home_team_total_fifa_points    23921 non-null  int64
#  8   away_team_total_fifa_points    23921 non-null  int64
#  9   home_team_score                23921 non-null  int64
#  10  away_team_score                23921 non-null  int64
#  11  tournament                     23921 non-null  object
# ...

# %%
df.describe()
# Out:
#        home_team_fifa_rank  away_team_fifa_rank  home_team_total_fifa_points  \
# count         23921.000000         23921.000000                 23921.000000
# mean             77.854688            80.797375                   323.401488
# std              52.355225            53.232902                   500.825725
# min               1.000000             1.000000                     0.000000
# 25%              33.000000            36.000000                     0.000000
# 50%              71.000000            73.000000                     0.000000
# 75%             115.000000           119.000000                   547.000000
# max             211.000000           211.000000                  2164.000000
#
#        away_team_total_fifa_points  home_team_score  away_team_score  \
# count                 23921.000000     23921.000000     23921.000000
# mean                    315.453576         1.609214         1.068266
# ...

# %%
df.columns
# Out:
# Index(['date', 'home_team', 'away_team', 'home_team_continent',
#        'away_team_continent', 'home_team_fifa_rank', 'away_team_fifa_rank',
#        'home_team_total_fifa_points', 'away_team_total_fifa_points',
#        'home_team_score', 'away_team_score', 'tournament', 'city', 'country',
#        'neutral_location', 'shoot_out', 'home_team_result',
#        'home_team_goalkeeper_score', 'away_team_goalkeeper_score',
#        'home_team_mean_defense_score', 'home_team_mean_offense_score',
#        'home_team_mean_midfield_score', 'away_team_mean_defense_score',
#        'away_team_mean_offense_score', 'away_team_mean_midfield_score'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# date                                 0
# home_team                            0
# away_team                            0
# home_team_continent                  0
# away_team_continent                  0
# home_team_fifa_rank                  0
# away_team_fifa_rank                  0
# home_team_total_fifa_points          0
# away_team_total_fifa_points          0
# home_team_score                      0
# away_team_score                      0
# tournament                           0
# city                                 0
# country                              0
# neutral_location                     0
# shoot_out                            0
# home_team_result                     0
# home_team_goalkeeper_score       15542
# away_team_goalkeeper_score       15826
# home_team_mean_defense_score     16134
# home_team_mean_offense_score     15411
# home_team_mean_midfield_score    15759
# away_team_mean_defense_score     16357
# away_team_mean_offense_score     15609
# ...

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# date                              0.000000
# home_team                         0.000000
# away_team                         0.000000
# home_team_continent               0.000000
# away_team_continent               0.000000
# home_team_fifa_rank               0.000000
# away_team_fifa_rank               0.000000
# home_team_total_fifa_points       0.000000
# away_team_total_fifa_points       0.000000
# home_team_score                   0.000000
# away_team_score                   0.000000
# tournament                        0.000000
# city                              0.000000
# country                           0.000000
# neutral_location                  0.000000
# shoot_out                         0.000000
# home_team_result                  0.000000
# home_team_goalkeeper_score       64.972200
# away_team_goalkeeper_score       66.159441
# home_team_mean_defense_score     67.447013
# home_team_mean_offense_score     64.424564
# home_team_mean_midfield_score    65.879353
# ...

# %%
Value_Missing = df.isnull().sum().sort_values(ascending = False)
percent_missing = (df.isnull().sum() * 100 / len(df)).round(2).sort_values(ascending = False)
missing_data = pd.concat([Value_Missing, percent_missing], axis = 1, keys = ['Total', 'Percent'])
f, ax = plt.subplots(figsize = (10, 5))
plt.xticks(rotation = '90')
cplot = sns.barplot(x = missing_data.index, y = missing_data['Percent'], palette = 'bone_r', lw = 2, ec = 'black')
for count in cplot.patches:
    height = count.get_height()
    ax.annotate('{}'.format(height),xy = (count.get_x() + count.get_width()/2, height),
                    ha = 'center', va = 'bottom', size = 11, xytext = (0, 3), textcoords = 'offset points')
cplot.set_title('Missing Value Inspection', fontsize = 20, weight = 'bold')
cplot.set_ylabel('Count', fontsize = 15)
cplot.set_xlabel('Features', fontsize = 15);

# %%
df1 = df.dropna()

# %%
df1.isnull().sum()
# Out:
# date                             0
# home_team                        0
# away_team                        0
# home_team_continent              0
# away_team_continent              0
# home_team_fifa_rank              0
# away_team_fifa_rank              0
# home_team_total_fifa_points      0
# away_team_total_fifa_points      0
# home_team_score                  0
# away_team_score                  0
# tournament                       0
# city                             0
# country                          0
# neutral_location                 0
# shoot_out                        0
# home_team_result                 0
# home_team_goalkeeper_score       0
# away_team_goalkeeper_score       0
# home_team_mean_defense_score     0
# home_team_mean_offense_score     0
# home_team_mean_midfield_score    0
# away_team_mean_defense_score     0
# away_team_mean_offense_score     0
# away_team_mean_midfield_score    0
# dtype: int64

# %%
Value_Missing = df1.isnull().sum().sort_values(ascending = False)
percent_missing = (df1.isnull().sum() * 100 / len(df)).round(2).sort_values(ascending = False)
missing_data = pd.concat([Value_Missing, percent_missing], axis = 1, keys = ['Total', 'Percent'])
f, ax = plt.subplots(figsize = (10, 5))
plt.xticks(rotation = '90')
cplot = sns.barplot(x = missing_data.index, y = missing_data['Percent'], palette = 'bone_r', lw = 2, ec = 'black')
for count in cplot.patches:
    height = count.get_height()
    ax.annotate('{}'.format(height),xy = (count.get_x() + count.get_width()/2, height),
                    ha = 'center', va = 'bottom', size = 11, xytext = (0, 3), textcoords = 'offset points')
cplot.set_title('Missing Value Inspection', fontsize = 20, weight = 'bold')
cplot.set_ylabel('Count', fontsize = 15)
cplot.set_xlabel('Features', fontsize = 15);

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23921 entries, 0 to 23920
# Data columns (total 25 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   date                           23921 non-null  object
#  1   home_team                      23921 non-null  object
#  2   away_team                      23921 non-null  object
#  3   home_team_continent            23921 non-null  object
#  4   away_team_continent            23921 non-null  object
#  5   home_team_fifa_rank            23921 non-null  int64
#  6   away_team_fifa_rank            23921 non-null  int64
#  7   home_team_total_fifa_points    23921 non-null  int64
#  8   away_team_total_fifa_points    23921 non-null  int64
#  9   home_team_score                23921 non-null  int64
#  10  away_team_score                23921 non-null  int64
#  11  tournament                     23921 non-null  object
# ...

# %%
df1.ndim
# Out:
# 2

# %%
df1.mean()
# Out:
# C:\Users\SREERAG E R\AppData\Local\Temp\ipykernel_14284\2053335143.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df1.mean()
# home_team_fifa_rank               32.233790
# away_team_fifa_rank               34.515919
# home_team_total_fifa_points      749.075064
# away_team_total_fifa_points      731.586335
# home_team_score                    1.422961
# away_team_score                    1.069022
# neutral_location                   0.240530
# home_team_goalkeeper_score        78.025564
# away_team_goalkeeper_score        76.942366
# home_team_mean_defense_score      76.862933
# home_team_mean_offense_score      78.093307
# home_team_mean_midfield_score     78.137369
# away_team_mean_defense_score      76.191239
# away_team_mean_offense_score      77.547757
# away_team_mean_midfield_score     77.399954
# ...

# %%
df1.median()
# Out:
# C:\Users\SREERAG E R\AppData\Local\Temp\ipykernel_14284\2279417019.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df1.median()
# home_team_fifa_rank               26.0
# away_team_fifa_rank               29.0
# home_team_total_fifa_points      759.0
# away_team_total_fifa_points      726.0
# home_team_score                    1.0
# away_team_score                    1.0
# neutral_location                   0.0
# home_team_goalkeeper_score        78.0
# away_team_goalkeeper_score        77.0
# home_team_mean_defense_score      76.5
# home_team_mean_offense_score      77.7
# home_team_mean_midfield_score     77.8
# away_team_mean_defense_score      76.0
# away_team_mean_offense_score      77.0
# away_team_mean_midfield_score     77.2
# dtype: float64

# %%
df1.mode()
# Out:
#          date home_team away_team home_team_continent away_team_continent  \
# 0  2022-03-29    Mexico  Paraguay              Europe              Europe
#
#    home_team_fifa_rank  away_team_fifa_rank  home_team_total_fifa_points  \
# 0                    3                    4                            0
#
#    away_team_total_fifa_points  home_team_score  ...  shoot_out  \
# 0                            0                1  ...         No
#
#   home_team_result home_team_goalkeeper_score away_team_goalkeeper_score  \
# 0              Win                       75.0                       75.0
#
#    home_team_mean_defense_score home_team_mean_offense_score  \
# 0                          77.0                         76.3
#
#   home_team_mean_midfield_score  away_team_mean_defense_score  \
# 0                          76.2                          77.0
#
#    away_team_mean_offense_score  away_team_mean_midfield_score
# 0                          76.3                           76.2
#
# ...

# %%
df1.std()
# Out:
# C:\Users\SREERAG E R\AppData\Local\Temp\ipykernel_14284\3039516898.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df1.std()
# home_team_fifa_rank               25.648850
# away_team_fifa_rank               25.902235
# home_team_total_fifa_points      616.813901
# away_team_total_fifa_points      608.315315
# home_team_score                    1.261324
# away_team_score                    1.082220
# neutral_location                   0.427455
# home_team_goalkeeper_score         6.993375
# away_team_goalkeeper_score         7.185716
# home_team_mean_defense_score       5.273799
# home_team_mean_offense_score       5.702442
# home_team_mean_midfield_score      5.097690
# away_team_mean_defense_score       5.218066
# away_team_mean_offense_score       5.557612
# away_team_mean_midfield_score      5.133342
# ...

# %%
df1.var()
# Out:
# C:\Users\SREERAG E R\AppData\Local\Temp\ipykernel_14284\2870725145.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df1.var()
# home_team_fifa_rank                 657.863507
# away_team_fifa_rank                 670.925769
# home_team_total_fifa_points      380459.388367
# away_team_total_fifa_points      370047.522937
# home_team_score                       1.590937
# away_team_score                       1.171200
# neutral_location                      0.182718
# home_team_goalkeeper_score           48.907296
# away_team_goalkeeper_score           51.634520
# home_team_mean_defense_score         27.812952
# home_team_mean_offense_score         32.517840
# home_team_mean_midfield_score        25.986441
# away_team_mean_defense_score         27.228210
# away_team_mean_offense_score         30.887047
# ...

# %%
correlation = df1.corr()
correlation
# Out:
#                                home_team_fifa_rank  away_team_fifa_rank  \
# home_team_fifa_rank                       1.000000             0.119551
# away_team_fifa_rank                       0.119551             1.000000
# home_team_total_fifa_points              -0.225677             0.017210
# away_team_total_fifa_points              -0.030116            -0.189737
# home_team_score                          -0.180358             0.172991
# away_team_score                           0.144821            -0.188304
# neutral_location                         -0.105860            -0.029413
# home_team_goalkeeper_score               -0.583543            -0.106319
# away_team_goalkeeper_score               -0.100077            -0.576377
# home_team_mean_defense_score             -0.675188            -0.110538
# home_team_mean_offense_score             -0.667324            -0.107250
# home_team_mean_midfield_score            -0.695493            -0.107359
# ...

# %%
# hist () function in matplotlib helps the users to create histograms,reads the array of a numpy and sends it as an argument to the function
df1.away_team_fifa_rank.plot.hist()
plt.show()

# %%
# NUMERICAL - NUMERICAL ASSOCIATIONS
plt.scatter(df.home_team_fifa_rank	,df.away_team_fifa_rank)
plt.show()

# %%
sns.boxplot(df1.home_team_total_fifa_points)
plt.show()
# Out:
# D:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df1.home_team_fifa_rank.value_counts(normalize=True).plot.barh()
plt.show()

# %% [markdown]
# ### From the above bar graph we can plot for the home_team_fifa_rank.value_counts

# %%
df.tournament.value_counts(normalize=True).plot.pie()
plt.show()

# %% [markdown]
# ## from the above pie char we can find that friendly matches have more tournament value counts

# %%
df.home_team .value_counts(normalize=True).plot.pie()
plt.show()

# %%
df.tournament.value_counts()
# Out:
# Friendly                                8558
# FIFA World Cup qualification            5528
# UEFA Euro qualification                 1723
# African Cup of Nations qualification    1274
# AFC Asian Cup qualification              541
#                                         ...
# AFF Championship qualification             2
# Copa América qualification                 2
# Copa Confraternidad                        1
# TIFOCO Tournament                          1
# CONMEBOL–UEFA Cup of Champions             1
# Name: tournament, Length: 82, dtype: int64

# %% [markdown]
# ## From the above bar graph we can plot for the home team value counts

# %%
df["country"].value_counts()
# Out:
# USA                      1003
# South Africa              505
# United Arab Emirates      462
# Qatar                     461
# France                    445
#                          ...
# Réunion                     2
# Afghanistan                 2
# Tahiti                      2
# Saint Martin                2
# Serbia and Montenegro       1
# Name: country, Length: 217, dtype: int64

# %% [markdown]
# ## From the above plotting scatter plot of home_team_total_fifa_point and  home_team_total_fifa_pointcolumns

# %%
#if(normalize=True) then the object return will contain the relative frequencies of unique values.
df["country"].value_counts(normalize=True)
# Out:
# USA                      0.041930
# South Africa             0.021111
# United Arab Emirates     0.019314
# Qatar                    0.019272
# France                   0.018603
#                            ...
# Réunion                  0.000084
# Afghanistan              0.000084
# Tahiti                   0.000084
# Saint Martin             0.000084
# Serbia and Montenegro    0.000042
# Name: country, Length: 217, dtype: float64

# %%
#short table showing the relationship between two or more variables
pd.crosstab(df["country"],df.tournament)
# Out:
# tournament   ABCS Tournament  AFC Asian Cup  AFC Asian Cup qualification  \
# country
# Afghanistan                0              0                            0
# Albania                    0              0                            0
# Algeria                    0              0                            0
# Andorra                    0              0                            0
# Angola                     0              0                            0
# ...                      ...            ...                          ...
# Vietnam                    0              8                           18
# Wales                      0              0                            0
# Yemen                      0              0                            6
# Zambia                     0              0                            0
# Zimbabwe                   0              0                            0
#
# tournament   AFC Challenge Cup  AFC Challenge Cup qualification  \
# country
# ...

# %%
df.home_team_total_fifa_points	.plot.hist()
plt.show()

# %%
sns.boxplot(df.away_team_fifa_rank)
plt.show()
# Out:
# D:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df.home_team_fifa_rank.plot.hist()
plt.show()

# %% [markdown]
# sns.heatmap(correlation,annot=True,
#            xticklabels = correlation.columns.values,
#            yticklabels = correlation.columns.values);
# plt.show()

# %%
sns.boxplot(df.home_team_fifa_rank)
plt.show()
# Out:
# D:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df.home_team_score.plot.hist()
plt.show()

# %% [markdown]
# # finding relation between ranks and points of away and home teams

# %%
sns.heatmap(df[["home_team_fifa_rank","away_team_fifa_rank","home_team_total_fifa_points","away_team_total_fifa_points","home_team_score"]].corr(),annot=True,cmap="Reds")
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(df[["home_team_fifa_rank","away_team_fifa_rank","home_team_total_fifa_points","away_team_total_fifa_points","home_team_score"]].corr(),annot=True,cmap="Reds")
# Out:
# <AxesSubplot:>

# %%
 sns.pairplot(data=df1,vars=["home_team_fifa_rank","away_team_fifa_rank","home_team_total_fifa_points"])
plt.show()

# %%
sns.heatmap(df[["home_team_fifa_rank","away_team_fifa_rank","home_team_total_fifa_points","away_team_total_fifa_points","home_team_score"]].corr(),annot=True,cmap="Blues")
# Out:
# <AxesSubplot:>

# %%
#grouping the home_team_total_fifa_points to find the mean of the home_team_fifa_rank with respect to gender
df.groupby("home_team_total_fifa_points")["home_team_fifa_rank"].mean()
# Out:
# home_team_total_fifa_points
# 0        74.60119
# 1       207.00000
# 2       204.00000
# 3       206.00000
# 4       204.50000
#           ...
# 2017     14.00000
# 2036     12.00000
# 2124      5.00000
# 2160      4.00000
# 2164      2.00000
# Name: home_team_fifa_rank, Length: 1686, dtype: float64

# %%
#median
df.groupby("home_team_total_fifa_points")["home_team_fifa_rank"].median()
# Out:
# home_team_total_fifa_points
# 0        68.0
# 1       207.0
# 2       204.0
# 3       206.0
# 4       204.0
#         ...
# 2017     14.0
# 2036     12.0
# 2124      5.0
# 2160      4.0
# 2164      2.0
# Name: home_team_fifa_rank, Length: 1686, dtype: float64

# %%
#plotting bar graph of home_team_total_fifa_points and home_team_fifa_rank 0f mean and median
df.groupby("home_team_total_fifa_points")["home_team_fifa_rank"].aggregate(["mean","median"]).plot.bar()
plt.show()

# %%
#plotting bar graph ofaway_team_score and home_team_score? 0f mean and median
df.groupby("away_team_score")["home_team_score"].aggregate(["mean","median"]).plot.bar()
plt.show()
